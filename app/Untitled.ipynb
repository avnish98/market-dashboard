# %%
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 9.7 MB 5.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.4 MB 3.9 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("nifty_500_metadata.csv")

# %%
dic = df[df['symbol'] == '3MINDIA'].to_dict(orient='record')[0]

# %%
type(dic['adhocMargin'])
# Out:
# float

# %%
import math
(math.isnan(dic['adhocMargin']))
# Out:
# True

# %%
metadict = df[['symbol', 'companyName']].to_dict(orient='records')
val_dict = [{'label':item['symbol'], 'value':item['companyName']} for item in metadict]

# %%
val_dict
# Out:
# [{'label': '3MINDIA', 'value': '3M India Limited'},
#  {'label': 'ABB', 'value': 'ABB India Limited'},
#  {'label': 'POWERINDIA',
#   'value': 'ABB Power Products and Systems India Limited'},
#  {'label': 'ACC', 'value': 'ACC Limited'},
#  {'label': 'AIAENG', 'value': 'AIA Engineering Limited'},
#  {'label': 'APLAPOLLO', 'value': 'APL Apollo Tubes Limited'},
#  {'label': 'AUBANK', 'value': 'AU Small Finance Bank Limited'},
#  {'label': 'AARTIDRUGS', 'value': 'Aarti Drugs Limited'},
#  {'label': 'AARTIIND', 'value': 'Aarti Industries Limited'},
#  {'label': 'AAVAS', 'value': 'Aavas Financiers Limited'},
#  {'label': 'ABBOTINDIA', 'value': 'Abbott India Limited'},
#  {'label': 'ADANIENT', 'value': 'Adani Enterprises Limited'},
#  {'label': 'ADANIGREEN', 'value': 'Adani Green Energy Limited'},
#  {'label': 'ADANIPORTS',
#   'value': 'Adani Ports and Special Economic Zone Limited'},
#  {'label': 'ATGL', 'value': 'Adani Total Gas Limited'},
# ...
