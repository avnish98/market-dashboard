# %%
# !pip install nsetools pandas nsepy
# Out:
# ...
#      |████████████████████████████████| 9.7 MB 6.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 115 kB 7.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.4 MB 6.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 82 kB 1.3 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 5.4 MB 7.2 MB/s eta 0:00:01
# ...
#   Created wheel for nsepy: filename=nsepy-0.8-py3-none-any.whl size=36083 sha256=8e4948fafec60d581675353a21451e7b9ba6d455eb63572d4c7d36012eed18f8
#   Stored in directory: /home/jovyan/.cache/pip/wheels/b9/2c/cb/d74199e422a1dbc20297d10cfff9c54d03e0b5c6694d49ccdd
# Successfully built nsepy
# ...

# %%
from fetcher import Nifty500

# %%
nft = Nifty500()

# %%
nft.update_ohlc()
# Out:
# Exception: index -1 is out of bounds for axis 0 with size 0 for ticker POWERINDIA
# ATGL is outdated by 377 days
# ADANITRANS is outdated by 377 days
# ABCAPITAL is outdated by 377 days
# ABFRL is outdated by 377 days
# ADVENZYMES is outdated by 377 days
# AEGISCHEM is outdated by 377 days
# AFFLE is outdated by 377 days
# AJANTPHARM is outdated by 377 days
# AKZOINDIA is outdated by 377 days
# ALEMBICLTD is outdated by 377 days
# APLLTD is outdated by 377 days
# ALKEM is outdated by 377 days
# ALKYLAMINE is outdated by 377 days
# Exception: index -1 is out of bounds for axis 0 with size 0 for ticker ALOKINDS
# AMARAJABAT is outdated by 377 days
# AMBER is outdated by 377 days
# AMBUJACEM is outdated by 377 days
# APOLLOHOSP is outdated by 377 days
# APOLLOTYRE is outdated by 377 days
# ASHOKLEY is outdated by 377 days
# ASHOKA is outdated by 377 days
# ASIANPAINT is outdated by 377 days
# ASTERDM is outdated by 377 days
# ASTRAZEN is outdated by 377 days
# ...

# %%
nft.fetch_metadata(update_list=True)
# Out:
# Progress: 0.2% Last ticker: 3MINDIA
# Progress: 0.4% Last ticker: ABB
# Progress: 0.6% Last ticker: POWERINDIA
# Progress: 0.8% Last ticker: ACC
# Progress: 1.0% Last ticker: AIAENG
# Progress: 1.2% Last ticker: APLAPOLLO
# Progress: 1.4% Last ticker: AUBANK
# Progress: 1.6% Last ticker: AARTIDRUGS
# Progress: 1.8% Last ticker: AARTIIND
# Progress: 2.0% Last ticker: AAVAS
# Progress: 2.2% Last ticker: ABBOTINDIA
# Progress: 2.4% Last ticker: ADANIENT
# Progress: 2.59% Last ticker: ADANIGREEN
# Progress: 2.79% Last ticker: ADANIPORTS
# Progress: 2.99% Last ticker: ATGL
# Progress: 3.19% Last ticker: ADANITRANS
# Progress: 3.39% Last ticker: ABCAPITAL
# Progress: 3.59% Last ticker: ABFRL
# Progress: 3.79% Last ticker: ADVENZYMES
# Progress: 3.99% Last ticker: AEGISCHEM
# Progress: 4.19% Last ticker: AFFLE
# Progress: 4.39% Last ticker: AJANTPHARM
# Progress: 4.59% Last ticker: AKZOINDIA
# Progress: 4.79% Last ticker: ALEMBICLTD
# Progress: 4.99% Last ticker: APLLTD
# ...
